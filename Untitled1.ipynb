# %%
min_quality=int(40)
up_lim=int(input('Enter Maximum Load Limit '))
low_lim=int(input('Enter Lower Load Limit '))
power_consumption=int(input('Enter Power Consumption '))
# Out:
# Enter Maximum Load Limit 3000
# Enter Lower Load Limit 300
# Enter Power Consumption 10

# %%
def power_center(Traffic1,Traffic2,Traffic3,Traffic4,Traffic5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t):
    s=int(0)
    shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
    
    if t!=1:
        #STATION ONE CHECK
        if Traffic1<lowerlimit:
            shed1=int(Traffic1)
            print('shed1 before Qos call '+str(shed1))
            Traffic1=int(0)
            QoS1(shed1,s)
            print('')
            print('Station One Going To Sleep')
            print('')
            s+=1
            tt.home()
            sleep1()
        elif Traffic1>upperlimit:
            print('')
            print('Station One Over Loaded, Shedding Load')
            print('')
            tt.home()
            unstable1()
            if Traffic1>up_lim:
                shed1=int(Traffic1-up_lim)
                Traffic1=upperlimit
                print('Traffic1 is now equal to '+str(Traffic1))
        else:
            print('')
            print('Station One In Good Condition')
            print('')
            tt.home()
            stable1()

        if shed1!="":
            if t!=2:
                Traffic2=int(shed1+Traffic2)
            else:
                Traffic3=int(shed1+Traffic3)
            print('')
            print('value of Traffic 2 is '+str(Traffic2))
            print('load shed from Traffic1 is '+str(shed1))
            shed1=int(0)
    else:
        print('Skipping Station 1')
        shed1=0
        
    if t!=2:
        #STATION TWO CHECK
        if Traffic2<lowerlimit:
            shed2=int(Traffic2)
            Traffic2=int(0)
            print('shed2 before Qos call '+str(shed2))
            QoS2(shed2,s)
            print('')
            print('Station Two Going To Sleep')
            print('')
            s+=1
            sleep2()
        elif Traffic2>upperlimit:
            print('')
            print('Station Two Over Loaded, Shedding Load')
            print('')
            unstable2()
            if Traffic2>up_lim:
                shed2=int(Traffic2-up_lim)
                Traffic2=upperlimit
                print('Traffic2 is now equal to '+str(Traffic2))
        else:
            print('')
            print('Station Two In Good Condition')
            print('')
            stable2()

        if shed2!="":
            if t!=3:
                Traffic3=int(Traffic3+shed2)
            else:
                Traffic4=int(Traffic4+shed2)
            print('load shed from Traffic2 is '+str(shed2))
            shed2=int(0)

    else:
        print('Skipping Station 2')
        shed2=int(0)
        
    if t!=3:
        #STATION THREE CHECK
        if Traffic3<lowerlimit:
            shed3=int(Traffic3)
            Traffic3=int(0)
            print('shed3 before Qos call '+str(shed3))
            QoS3(shed3,s)
            print('')
            print('Station Three Going To Sleep')
            print('')
            s+=1
            sleep3()
        elif Traffic3>upperlimit:
            print('')
            print('Station Three Over Loaded, Shedding Load')
            print('')
            unstable3()
            if Traffic3>up_lim:
                shed3=int(Traffic3-up_lim)
                Traffic3=upperlimit
                print('Traffic3 is now equal to '+str(Traffic3))
        else:
            print('')
            print('Station Three In Good Condition')
            print('')
            stable3()

        if shed3!="":
            if t!=4:
                Traffic4=int(Traffic4+shed3)
            else:
                Traffic5=int(Traffic5+shed3)
            print('load shed from Traffic3 is '+str(shed3))
            shed3=int(0)
    else:
        print('Skipping Station 3')
        shed3=int(0)
        
    if t!=4:
        #STATION FOUR CHECK
        if Traffic4<lowerlimit:
            shed4=int(Traffic4)
            Traffic4=int(0)
            print('shed4 before Qos call '+str(shed4))
            QoS4(shed4,s)
            print('')
            print('Station Four Going To Sleep')
            print('')
            s+=1
            sleep4()
        elif Traffic4>upperlimit:
            print('')
            print('Station Four Over Loaded, Shedding Load')
            print('')
            unstable4()
            if Traffic4>up_lim:
                shed4=int(Traffic4-up_lim)
                Traffic4=upperlimit
                print('Traffic4 is now equal to '+str(Traffic4))
        else:
            print('')
            print('Station Four In Good Condition')
            print('')
            stable4()

        if shed4!="":
            if t!=5:
                Traffic5=int(Traffic5+shed4)
            else:
                Traffic6=int(Traffic6+shed4)
            print('load shed from Traffic4 is '+str(shed4))
            shed4=int(0)
    else:
        print('Skipping Station 4')
        shed4=int(0)
            
    if t!=5:
        #STATION FIVE CHECK    
        if Traffic5<lowerlimit:
            shed5=int(Traffic5)
            Traffic5=int(0)
            print('shed5 before Qos call '+str(shed5))
            QoS5(shed5,s)
            print('')
            print('Station Five Going To Sleep')
            print('')
            s+=1
            sleep5()
        elif Traffic5>upperlimit:
            print('')
            print('Station Five Over Loaded, Shedding Load')
            print('')
            unstable5()
            if Traffic5>up_lim:
                shed5=int(Traffic5-up_lim)
                Traffic5=upperlimit
                print('Traffic5 is now equal to '+str(Traffic5))
        else:
            print('')
            print('Station Five In Good Condition')
            print('')
            stable5()

        if shed5!="":
            if t!=6:
                Traffic6=int(Traffic6+shed5)
            else:
                Traffic7=int(Traffic7+shed5)
            print('load shed from Traffic5 is '+str(shed5))   
            shed5=int(0)
        
    else:
        print('Skipping Station 5')
        shed5=int(0) 
        
    if t!=6:
        #STATION SIX CHECK
        if Traffic6<lowerlimit:
            shed6=int(Traffic6)
            Traffic6=int(0)
            print('shed6 before Qos call '+str(shed6))
            QoS6(shed6,s)
            print('')
            print('Station Six Going To Sleep')
            print('')
            s+=1
            sleep6()
        elif Traffic6>upperlimit:
            print('')
            print('Station Six Over Loaded, Shedding Load')
            print('')
            unstable6()
            if Traffic6>up_lim:
                shed6=int(Traffic6-up_lim)
                Traffic6=upperlimit
                print('Traffic6 is now equal to '+str(Traffic6))
        else:
            print('')
            print('Station Six In Good Condition')
            print('')
            stable6()

        if shed6!="":
            if t!=7:
                Traffic7=int(Traffic7+shed6)
            else:
                Traffic1=int(Traffic1+shed6)
            print('load shed from Traffic6 is '+str(shed6))   
            shed6=int(0)
    else:
        print('Skipping Station 6')
        shed6=int(0)
        
    if t!=7:
        #STATION SEVEN CHECK
        if Traffic7<lowerlimit:
            shed7=int(Traffic7)
            Traffic7=int(0)
            print('shed7 befor Qos call '+str(shed7))
            QoS7(shed7,s)
            print('')
            print('Station Seven Going To Sleep')
            print('')
            s+=1
            sleep7()
        elif Traffic7>upperlimit:
            print('')
            print('Station Seven Over Loaded, Shedding Load')
            print('')
            unstable7()
            if Traffic7>up_lim:
                print(Traffic7)
                shed7=int(Traffic7-up_lim)
                Traffic7=upperlimit
                print('Traffic7 is now equal to '+str(Traffic7))
        else:
            print('')
            print('Station Seven In Good Condition')
            print('')
            print( 'Load shed from Traffic7 is '+str(shed7))
            stable7()
    else:
        print('Skipping Station 7')
        
    if shed7==int(0) or Traffic1==Traffic2==Traffic3==Traffic4==Traffic5==Traffic6==Traffic7:
        print('')
        print('value for s is '+str(s))
        print('Process Terminated')
        print('Current Load Value Of Station 1 is '+str(Traffic1))
        print('Current Load Value Of Station 2 is '+str(Traffic2))
        print('Current Load Value Of Station 3 is '+str(Traffic3))
        print('Current Load Value Of Station 4 is '+str(Traffic4))
        print('Current Load Value Of Station 5 is '+str(Traffic5))
        print('Current Load Value Of Station 6 is '+str(Traffic6))
        print('Current Load Value Of Station 7 is '+str(Traffic7))
        
        tt.hideturtle()
        tt.home()
        if Traffic1<low_lim:
            sleep1()
        elif Traffic1>up_lim:
            unstable1()
        else:
            stable1()
            
        if Traffic2<low_lim:
            sleep2()
        elif Traffic2>up_lim:
            unstable2()
        else:
            stable2()
            
        if Traffic3<low_lim:
            sleep3()
        elif Traffic1>up_lim:
            unstable3()
        else:
            stable3()
            
        if Traffic4<low_lim:
            sleep4()
        elif Traffic4>up_lim:
            unstable4()
        else:
            stable4()
            
        if Traffic5<low_lim:
            sleep5()
        elif Traffic5>up_lim:
            unstable5()
        else:
            stable5()
        
        if Traffic6<low_lim:
            sleep6()
        elif Traffic6>up_lim:
            unstable6()
        else:
            stable6()
            
        if Traffic7<low_lim:
            sleep7()
        elif Traffic7>up_lim:
            unstable7()
        else:
            stable7()
        tt.done()
        
        
        import matplotlib.pyplot as plt; plt.rcdefaults()
        import numpy as np
        import matplotlib.pyplot as plt

        Traffic=('Traffic1','Traffic2','Traffic3','Traffic4','Traffic5','Traffic6','Traffic7')
        y_pos = np.arange(len(Traffic))
        Values= (Traffic1,Traffic2,Traffic3,Traffic4,Traffic5,Traffic6,Traffic7)

        plt.bar(y_pos, Values, align='center', alpha=0.5)
        plt.xticks(y_pos,Traffic)
        plt.ylabel('No Of Users')
        plt.title('Final Active User Visualization')

        plt.show()
        
    else:
        print('load shed from Traffic7 is '+str(shed7))
        if t!=1:
            Traffic1=int(Traffic1+shed7)
        else:
            Traffic2=int(Traffic2+shed7)
        shed7=int(0)
        power_center(Traffic1,Traffic2,Traffic3,Traffic4,Traffic5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
        
#Determining QoS Value by using number of users connected
def QoS1(shed1,s):
    print('shed1 immediately after call '+str(shed1))
    total_user=Traffic1+Traffic2+Traffic3+Traffic4+Traffic5+Traffic6+Traffic7
    print('Total users are '+str(total_user))
    mast_n=int(7-s)
    var=int(mast_n * up_lim)
    print(var)
    #print(total_user)
    Qos_constant=float(total_user/var)
    #print('Value for QoS constant is '+str(Qos_constant))
    Qos_val=int((1-Qos_constant)*100)
    print('QoS1 is '+str(Qos_val))
    if Qos_val<min_quality:
        #print(shed1)
        equalizer=int(low_lim-shed1)
        #print(equalizer)
        new_T1=int(equalizer+shed1)
        #print(new_T1)
        print('Traffic1 at Qos1 is now '+str(new_T1))
        #Traffic1==new_T1
        new_T7=Traffic7-equalizer
        if new_T7<0:
            print('Iteration Stopped due to  new_T7')
            new_T1=0
            print('')
            print('Starting Adjustment Process')
            print('')
            print('Determining Suitable Neigbour Station')
            TL=(Traffic2,Traffic3,Traffic4,Traffic5,Traffic6)
            D2=Traffic2-equalizer
            D3=Traffic3-equalizer
            D4=Traffic4-equalizer
            D5=Traffic5-equalizer
            D6=Traffic6-equalizer
            maxdet=max(D2,D3,D4,D5,D6)
            for index,traffic in enumerate (TL):
                if traffic-equalizer==maxdet:
                    new_T1=0
                    print(traffic)
                    print(index)
                    value=index+1
                    equalizer2=int(low_lim-shed1)
                    new_T1=equalizer2
                    print('value is '+str(value))
                    if value==2:
                        t=value
                        print('value 2 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T2=traffic-equalizer2
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(new_T1,new_T2,Traffic3,Traffic4,Traffic5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==3:
                        t=value
                        print('value 3 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T3=traffic-equalizer2
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(new_T1,Traffic2,new_T3,Traffic4,Traffic5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==4:
                        t=value
                        print('value 4 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T4=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(new_T1,Traffic2,Traffic3,new_T4,Traffic5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==5:
                        t=value
                        print('value 5 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T5=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(new_T1,Traffic2,Traffic3,Traffic4,new_T5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==6:
                        t=value
                        print('value 6 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T6=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(new_T1,Traffic2,Traffic3,Traffic4,Traffic5,new_T6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()

        else:
            #print(new_T7)
            t=0
            shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
            power_center(new_T1,Traffic2,Traffic3,Traffic4,Traffic5,Traffic6,new_T7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
            import sys
            sys.exit()

def QoS2(shed2,s):
    print('shed2 immediately after call '+str(shed2))
    total_user=Traffic1+Traffic2+Traffic3+Traffic4+Traffic5+Traffic6+Traffic7
    print('Total users are '+str(total_user))
    mast_n=int(7-s)
    var=int(mast_n * up_lim)
    print(var)
    #print(total_user)
    Qos_constant=float(total_user/var)
    #print('Value for QoS constant is '+str(Qos_constant))
    Qos_val=int((1-Qos_constant)*100)
    print('QoS2 is '+str(Qos_val))
    if Qos_val<min_quality:
        #print(shed2)
        equalizer=int(low_lim-shed2)
        #print(equalizer)
        new_T2=int(equalizer+shed2)
        #print(new_T2)
        new_T1=Traffic1-equalizer
        if new_T1<0:
            print('Iteration stopped due to new_T1')
            new_T2=0
            print('')
            print('Starting Adjustment Process')
            print('')
            print('Determining Suitable Neigbour Station')
            TL=(Traffic3,Traffic4,Traffic5,Traffic6,Traffic7)
            D3=Traffic3-equalizer
            D4=Traffic4-equalizer
            D5=Traffic5-equalizer
            D6=Traffic6-equalizer
            D7=Traffic7-equalizer
            maxdet=max(D3,D4,D5,D6,D7)
            for index,traffic in enumerate (TL):
                if traffic-equalizer==maxdet:
                    new_T2=0
                    print(traffic)
                    print(index)
                    value=index+1
                    equalizer2=int(low_lim-shed2)
                    new_T2=equalizer2
                    print('value is '+str(value))
                    if value==3:
                        t=value
                        print('value 3 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T3=traffic-equalizer2
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,new_T2,new_T3,Traffic4,Traffic5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==4:
                        t=value
                        print('value 4 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T4=traffic-equalizer2
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,new_T2,Traffic3,new_T4,Traffic5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==5:
                        t=value
                        print('value 5 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T5=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,new_T2,Traffic3,Traffic4,new_T5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==6:
                        t=value
                        print('value 6 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T6=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,new_T2,Traffic3,Traffic4,Traffic5,new_T6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==7:
                        t=value
                        print('value 7 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T7=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,new_T2,Traffic3,Traffic4,Traffic5,Traffic6,new_T7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()

        else:
            #print(new_T1)
            t=0
            shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
            power_center(new_T1,new_T2,Traffic3,Traffic4,Traffic5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
            import sys
            sys.exit()


def QoS3(shed3,s):
    print('shed3 immediately after call '+str(shed3))
    total_user=Traffic1+Traffic2+Traffic3+Traffic4+Traffic5+Traffic6+Traffic7
    print('Total users are '+str(total_user))
    mast_n=int(7-s)
    var=int(mast_n * up_lim)
    print(var)
    #print(total_user)
    Qos_constant=float(total_user/var)
    #print('Value for QoS constant is '+str(Qos_constant))
    Qos_val=int((1-Qos_constant)*100)
    print('QoS3 is '+str(Qos_val))
    if Qos_val<min_quality:
        #print(shed3)
        equalizer=int(low_lim-shed3)
        #print(equalizer)
        new_T3=int(equalizer+shed3)
        #print(new_T3)
        new_T2=Traffic2-equalizer
        if new_T2<0:
            print('Iteration Stopped Due to new_T2')
            new_T3=0
            print('')
            print('Starting Adjustment Process')
            print('')
            print('Determining Suitable Neigbour Station')
            TL=(Traffic1,Traffic4,Traffic5,Traffic6,Traffic7)
            D1=Traffic1-equalizer
            D4=Traffic4-equalizer
            D5=Traffic5-equalizer
            D6=Traffic6-equalizer
            D7=Traffic7-equalizer
            maxdet=max(D1,D4,D5,D6,D7)
            for index,traffic in enumerate (TL):
                if traffic-equalizer==maxdet:
                    new_T3=0
                    print(traffic)
                    print(index)
                    value=index+1
                    equalizer2=int(low_lim-shed3)
                    new_T3=equalizer2
                    print('value is '+str(value))
                    if value==1:
                        t=value
                        print('value 1 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T1=traffic-equalizer2
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(new_T1,Traffic2,new_T3,Traffic4,Traffic5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==4:
                        t=value
                        print('value 4 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T4=traffic-equalizer2
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,Traffic2,new_T3,new_T4,Traffic5,new_T6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==5:
                        t=value
                        print('value 5 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T5=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,Traffic2,new_T3,Traffic4,new_T5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==6:
                        t=value
                        print('value 6 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T6=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,Traffic2,new_T3,Traffic4,Traffic5,new_T6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==7:
                        t=value
                        print('value 7 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T7=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,Traffic2,new_T3,Traffic4,Traffic5,Traffic6,new_T7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()

        else:
            #print(new_T2)
            t=0
            shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
            power_center(Traffic1,new_T2,new_T3,Traffic4,Traffic5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
            import sys
            sys.exit()


def QoS4(shed4,s):
    print('shed4 immediately after call '+str(shed4))
    total_user=Traffic1+Traffic2+Traffic3+Traffic4+Traffic5+Traffic6+Traffic7
    print('Total users are '+str(total_user))
    mast_n=int(7-s)
    var=int(mast_n * up_lim)
    print(var)
    #print(total_user)
    Qos_constant=float(total_user/var)
    #print('Value for QoS constant is '+str(Qos_constant))
    Qos_val=int((1-Qos_constant)*100)
    print('QoS4 is '+str(Qos_val))
    if Qos_val<min_quality:
        #print(shed4)
        equalizer=int(low_lim-shed4)
        #print(equalizer)
        new_T4=int(equalizer+shed4)
        #print(new_T4)
        new_T3=Traffic3-equalizer
        if new_T3<0:
            new_T4=0
            print('Iteration Stopped Due to new_T3')
            print('')
            print('Starting Adjustment Process')
            print('')
            print('Determining Suitable Neigbour Station')
            TL=(Traffic1,Traffic2,Traffic5,Traffic6,Traffic7)
            D1=Traffic1-equalizer
            D2=Traffic2-equalizer
            D5=Traffic5-equalizer
            D6=Traffic6-equalizer
            D7=Traffic7-equalizer
            maxdet=max(D1,D2,D5,D6,D7)
            for index,traffic in enumerate (TL):
                if traffic-equalizer==maxdet:
                    new_T4=0
                    print(traffic)
                    print(index)
                    value=index+1
                    equalizer2=int(low_lim-shed4)
                    new_T4=equalizer2
                    print('value is '+str(value))
                    if value==1:
                        t=value
                        print('value 1 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T1=traffic-equalizer2
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(new_T1,Traffic2,Traffic3,new_T4,Traffic5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==2:
                        t=value
                        print('value 2 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T2=traffic-equalizer2
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,new_T2,Traffic3,new_T4,Traffic5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==5:
                        t=value
                        print('value 5 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T5=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,Traffic2,Traffic3,new_T4,new_T5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==6:
                        t=value
                        print('value 6 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T6=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,Traffic2,Traffic3,new_T4,Traffic5,new_T6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==7:
                        t=value
                        print('value 7 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T7=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,Traffic2,Traffic3,new_T4,Traffic5,Traffic6,new_T7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()

        else:
            #print(new_T3)
            t=0
            shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
            power_center(Traffic1,Traffic2,new_T3,new_T4,Traffic5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
            import sys
            sys.exit()


def QoS5(shed5,s):
    print('shed5 immediately after call '+str(shed5))
    total_user=Traffic1+Traffic2+Traffic3+Traffic4+Traffic5+Traffic6+Traffic7
    print('Total users are '+str(total_user))
    mast_n=int(7-s)
    var=int(mast_n * up_lim)
    print(var)
    #print(total_user)
    Qos_constant=float(total_user/var)
    #print('Value for QoS constant is '+str(Qos_constant))
    Qos_val=int((1-Qos_constant)*100)
    print('QoS5 is '+str(Qos_val))
    if Qos_val<min_quality:
        #print(shed5)
        equalizer=int(low_lim-shed5)
        #print(equalizer)
        new_T5=int(equalizer+shed5)
        #print(new_T5)
        new_T4=Traffic4-equalizer
        if new_T4<0:
            new_T5=0
            print('Iteration Stopped Due to new_T4')
            print('')
            print('Starting Adjustment Process')
            print('')
            print('Determining Suitable Neigbour Station')
            TL=(Traffic1,Traffic2,Traffic3,Traffic6,Traffic7)
            D1=Traffic1-equalizer
            D2=Traffic2-equalizer
            D3=Traffic3-equalizer
            D6=Traffic6-equalizer
            D7=Traffic7-equalizer
            maxdet=max(D1,D2,D3,D6,D7)
            for index,traffic in enumerate (TL):
                if traffic-equalizer==maxdet:
                    new_T5=0
                    print(traffic)
                    print(index)
                    value=index+1
                    equalizer2=int(low_lim-shed5)
                    new_T5=equalizer2
                    print('value is '+str(value))
                    if value==1:
                        t=value
                        print('value 1 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T1=traffic-equalizer2
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(new_T1,Traffic2,Traffic3,Traffic4,new_T5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==2:
                        t=value
                        print('value 2 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T2=traffic-equalizer2
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,new_T2,Traffic3,Traffic4,new_T5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==3:
                        t=value
                        print('value 3 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T3=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,Traffic2,new_T3,Traffic4,new_T5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==7:
                        t=value
                        print('value 7 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T7=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,Traffic2,Traffic3,Traffic4,new_T5,Traffic6,new_T7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==6:
                        t=value
                        print('value 6 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T6=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,Traffic2,Traffic3,Traffic4,new_T5,new_T6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()

        else:
            #print(new_T4)
            t=0
            shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
            power_center(Traffic1,Traffic2,Traffic3,new_T4,new_T5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
            import sys
            sys.exit()

        
def QoS6(shed6,s):
    print('shed6 immediately after call '+str(shed6))
    total_user=Traffic1+Traffic2+Traffic3+Traffic4+Traffic5+Traffic6+Traffic7
    print('Total users are '+str(total_user))
    mast_n=int(7-s)
    var=int(mast_n * up_lim)
    print(var)
    #print(total_user)
    Qos_constant=float(total_user/var)
    #print('Value for QoS constant is '+str(Qos_constant))
    Qos_val=int((1-Qos_constant)*100)
    print('QoS6 is '+str(Qos_val))
    if Qos_val<min_quality:
        #print(shed6)
        equalizer=int(low_lim-shed6)
        #print(equalizer)
        new_T6=int(equalizer+shed6)
        #print(new_T6)
        new_T5=Traffic5-equalizer
        if new_T5<0:
            new_T6=0
            print('Iteration Stopped Due to new_T5')
            print('')
            print('Starting Adjustment Process')
            print('')
            print('Determining Suitable Neigbour Station')
            TL=(Traffic1,Traffic2,Traffic3,Traffic4,Traffic7)
            D1=Traffic1-equalizer
            D2=Traffic2-equalizer
            D3=Traffic3-equalizer
            D4=Traffic4-equalizer
            D7=Traffic7-equalizer
            maxdet=max(D1,D2,D3,D4,D7)
            for index,traffic in enumerate (TL):
                if traffic-equalizer==maxdet:
                    new_T6=0
                    print(traffic)
                    print(index)
                    value=index+1
                    equalizer2=int(low_lim-shed6)
                    new_T6=equalizer2
                    print('value is '+str(value))
                    if value==1:
                        t=value
                        print('value 1 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T1=traffic-equalizer2
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(new_T1,Traffic2,Traffic3,Traffic4,Traffic5,new_T6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==2:
                        t=value
                        print('value 2 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T2=traffic-equalizer2
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,new_T2,Traffic3,Traffic4,Traffic5,new_T6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==3:
                        t=value
                        print('value 3 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T3=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,Traffic2,new_T3,Traffic4,Traffic5,new_T6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==4:
                        t=value
                        print('value 4 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T4=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,Traffic2,Traffic3,new_T4,Traffic5,new_T6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==7:
                        t=value
                        print('value 7 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T7=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,Traffic2,Traffic3,Traffic4,Traffic5,new_T6,new_T7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
            
        else:
            #print(new_T5)
            t=0
            shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
            power_center(Traffic1,Traffic2,Traffic3,Traffic4,new_T5,new_T6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
            import sys
            sys.exit()

        
def QoS7(shed7,s):
    print('shed7 immediately after call '+str(shed7))
    total_user=Traffic1+Traffic2+Traffic3+Traffic4+Traffic5+Traffic6+Traffic7
    print('Total users are '+str(total_user))
    mast_n=int(7-s)
    var=int(mast_n * up_lim)
    print(var)
    #print(total_user)
    Qos_constant=float(total_user/var)
    #print('Value for QoS constant is '+str(Qos_constant))
    Qos_val=int((1-Qos_constant)*100)
    print('QoS7 is '+str(Qos_val))
    if Qos_val<min_quality:
        print('This is shed7 '+str(shed7))
        equalizer=int(low_lim-shed7)
        print('')
        print('This is the equalizer '+str(equalizer))
        new_T7=int(equalizer+shed7)
        print('')
        print('This is new_T7 '+str(new_T7))
        new_T6=Traffic6-equalizer
        if new_T6<0:
            new_T7=0
            print('Iteration Stopped Due to new_T6')
            print('')
            print('Starting Adjustment Process')
            print('')
            print('Determining Suitable Neigbour Station')
            TL=(Traffic1,Traffic2,Traffic3,Traffic4,Traffic5)
            D1=Traffic1-equalizer
            D2=Traffic2-equalizer
            D3=Traffic3-equalizer
            D4=Traffic4-equalizer
            D5=Traffic5-equalizer
            maxdet=max(D1,D2,D3,D4,D5)
            for index,traffic in enumerate (TL):
                if traffic-equalizer==maxdet:
                    new_T7=0
                    print(traffic)
                    print(index)
                    value=index+1
                    equalizer2=int(low_lim-shed7)
                    new_T7=equalizer2
                    print('value is '+str(value))
                    if value==1:
                        t=value
                        print('value 1 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T1=traffic-equalizer2
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(new_T1,Traffic2,Traffic3,Traffic4,Traffic5,Traffic6,new_T7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==2:
                        t=value
                        print('value 2 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T2=traffic-equalizer2
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,new_T2,Traffic3,Traffic4,Traffic5,Traffic6,new_T7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==3:
                        t=value
                        print('value 3 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T3=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,Traffic2,New_T3,Traffic4,Traffic5,Traffic6,new_T7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==4:
                        t=value
                        print('value 4 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T4=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,Traffic2,Traffic3,new_T4,Traffic5,Traffic6,new_T7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    if value==5:
                        t=value
                        print('value 5 working')
                        print('calculated requirement is '+str(equalizer))
                        new_T5=traffic-equalizer
                        shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
                        power_center(Traffic1,Traffic2,Traffic3,Traffic4,new_T5,Traffic6,new_T7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
                        import sys
                        sys.exit()
                    
        else:
            print('')
            print('This is new_T6 '+str(new_T6))
            t=0
            shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
            power_center(Traffic1,Traffic2,Traffic3,Traffic4,Traffic5,new_T6,new_T7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
            import sys
            sys.exit()

import turtle as tt

def stable1():
    tt.color('green')
    tt.begin_fill()
    tt.forward(80)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(80)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.end_fill()

    
def unstable1():
    tt.color('red')
    tt.begin_fill()
    tt.forward(80)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(80)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.end_fill()
    
def sleep1():
    tt.color('blue')
    tt.begin_fill()
    tt.forward(80)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(80)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.end_fill()
    

def stable2():
    tt.color('green')
    tt.begin_fill()
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.end_fill()

    
def unstable2():
    tt.color('red')
    tt.begin_fill()
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.end_fill()
    
def sleep2():
    tt.color('blue')
    tt.begin_fill()
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.end_fill()
    
    
def stable3():
    tt.color('green')
    tt.begin_fill()
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(80)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(80)
    tt.end_fill()

def unstable3():
    tt.color('red')
    tt.begin_fill()
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(80)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(80)
    tt.end_fill()
    
def sleep3():
    tt.color('blue')
    tt.begin_fill()
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(80)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(80)
    tt.end_fill()


def stable4():
    tt.left(60)
    tt.forward(50)
    tt.color('green')
    tt.begin_fill()
    tt.left(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.end_fill()
    
def unstable4():
    tt.left(60)
    tt.forward(50)
    tt.color('red')
    tt.begin_fill()
    tt.left(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.end_fill()
    
def sleep4():
    tt.left(60)
    tt.forward(50)
    tt.color('blue')
    tt.begin_fill()
    tt.left(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.end_fill()
    
def stable5():
    tt.back(80)
    tt.color('green')
    tt.begin_fill()
    tt.right(120)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(60)
    tt.forward(50)
    tt.end_fill()

def unstable5():
    tt.back(80)
    tt.color('red')
    tt.begin_fill()
    tt.right(120)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(60)
    tt.forward(50)
    tt.end_fill()
    
def sleep5():
    tt.back(80)
    tt.color('blue')
    tt.begin_fill()
    tt.right(120)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(60)
    tt.forward(50)
    tt.end_fill()
    
def stable6():
    tt.back(50)
    tt.color('green')
    tt.begin_fill()
    tt.left(120)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(80)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(80)
    tt.end_fill()
    
def unstable6():
    tt.back(50)
    tt.color('red')
    tt.begin_fill()
    tt.left(120)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(80)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(80)
    tt.end_fill()    

def sleep6():
    tt.back(50)
    tt.color('blue')
    tt.begin_fill()
    tt.left(120)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(80)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(50)
    tt.left(60)
    tt.forward(80)
    tt.end_fill()
    
def stable7():
    tt.left(60)
    tt.forward(50)
    tt.color('green')
    tt.begin_fill()
    tt.left(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(50)
    tt.end_fill()

def unstable7():
    tt.left(60)
    tt.forward(50)
    tt.color('red')
    tt.begin_fill()
    tt.left(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(50)
    tt.end_fill()
    
def sleep7():
    tt.left(60)
    tt.forward(50)
    tt.color('blue')
    tt.begin_fill()
    tt.left(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(50)
    tt.right(60)
    tt.forward(80)
    tt.right(50)
    tt.end_fill()

# %%
upperlimit=up_lim
lowerlimit=low_lim
print('lower limit is '+str(low_lim))
Max_power_consumprion=power_consumption
minum_quality=min_quality
t=0
shed1=shed2=shed3=shed4=shed5=shed6=shed7=0
Traffic1=Traffic2=Traffic3=Traffic4=Traffic5=Traffic6=Traffic7=0
Traffic1=int(input('Enter Value For Power Station 1 Traffic '))
Traffic2=int(input('Enter Value For Power Station 2 Traffic '))
Traffic3=int(input('Enter Value For Power Station 3 Traffic '))
Traffic4=int(input('Enter Value For Power Station 4 Traffic '))
Traffic5=int(input('Enter Value For Power Station 5 Traffic '))
Traffic6=int(input('Enter Value For Power Station 6 Traffic '))
Traffic7=int(input('Enter Value For Power Station 7 Traffic '))

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

Traffic=('Traffic1','Traffic2','Traffic3','Traffic4','Traffic5','Traffic6','Traffic7')
y_pos = np.arange(len(Traffic))
Values= (Traffic1,Traffic2,Traffic3,Traffic4,Traffic5,Traffic6,Traffic7)

plt.bar(y_pos, Values, align='center', alpha=0.5)
plt.xticks(y_pos,Traffic)
plt.ylabel('No Of Users')
plt.title('Initial Active User Visualization')

plt.show()
power_center(Traffic1,Traffic2,Traffic3,Traffic4,Traffic5,Traffic6,Traffic7,shed1,shed2,shed3,shed4,shed5,shed6,shed7,t)
# Out:
# lower limit is 300
# Enter Value For Power Station 1 Traffic 2000
# Enter Value For Power Station 2 Traffic 0
# Enter Value For Power Station 3 Traffic 200
# Enter Value For Power Station 4 Traffic 2999
# Enter Value For Power Station 5 Traffic 2998
# Enter Value For Power Station 6 Traffic 2997
# Enter Value For Power Station 7 Traffic 2996
# Station One In Good Condition
#
#
# value of Traffic 2 is 0
# load shed from Traffic1 is 0
# shed2 before Qos call 0
# shed2 immediately after call 0
# Total users are 14190
# 21000
# QoS2 is 32
#
# Station One In Good Condition
#
#
# value of Traffic 2 is 300
# load shed from Traffic1 is 0
#
# Station Two In Good Condition
#
# load shed from Traffic2 is 0
# shed3 before Qos call 200
# shed3 immediately after call 200
# Total users are 14190
# 21000
# QoS3 is 32
# Iteration Stopped Due to new_T2
#
# Starting Adjustment Process
#
# Determining Suitable Neigbour Station
# 2999
# 1
# value is 2
#
# Station Three Going To Sleep
#
# ...
